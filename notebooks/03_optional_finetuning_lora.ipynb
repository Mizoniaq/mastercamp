# %% [markdown]
# # 03 - Extension COULD : modele reel & fine-tuning (non realise)
#
# Ce notebook documente les pistes **Could have**. Elles ne remplacent pas la
# baseline : elles ne viennent qu'apres une chaine stable, des metriques et une
# analyse d'erreurs (deja livrees).
#
# **Ce qui est fait dans ce depot :**
# - Vrai modele medical **MedGemma-4b-it** via le harnais de comparaison de prompts
#   (`eval/run_vlm_comparison.py`), avec metrique d'hallucination et validation sur
#   vraies radios (voir `docs/rapport.md` sections 6.2 et 6.3).
#
# **Ce qui n'est PAS realise (volontairement) :**
# - Fine-tuning LoRA/QLoRA (Gemma 4 / Unsloth, MedGemma PEFT). Le sujet precise
#   qu'un fine-tuning *non mesure* n'est pas une amelioration. Squelettes fournis :
#   `finetuning/gemma4_unsloth_lora_stub.py`, `finetuning/medgemma_peft_qlora_stub.py`.
#
# > Prototype pedagogique. Non destine au diagnostic. Validation par un professionnel qualifie requise.

# %%
# Le vrai modele s'utilise via le harnais (GPU + HF_TOKEN + licence MedGemma) :
#   HF_TOKEN=... python eval/run_vlm_comparison.py --model google/medgemma-4b-it
# Ici, on se contente d'afficher les stubs de fine-tuning (non executes).
from pathlib import Path
ROOT = Path('..').resolve()
for stub in ['finetuning/gemma4_unsloth_lora_stub.py', 'finetuning/medgemma_peft_qlora_stub.py']:
    print('---', stub, '---')
    print((ROOT / stub).read_text(encoding='utf-8'))
